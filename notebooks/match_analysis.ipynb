# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Analisando partida

# %%
with open('./data/match_example.json', 'rb') as f:
  match_content = json.loads(f.read())

participants = match_content['info']['participants']
participants_df = pd.DataFrame(participants)
participants_df
# Out:
#    allInPings  assistMePings  assists  baitPings  baronKills  basicPings  \
# 0           0              0        3          0           0           0
# 1           0              0        5          0           0           0
# 2           0              0        4          0           0           0
# 3           0              0        3          0           0           0
# 4           0              3       16          0           0           0
# 5           0              1        0          0           0           0
# 6          10              0        1          0           0           0
# 7           0              0        1          0           0           0
# 8           1              1        2          0           0           0
# 9           0              6        5          0           0           0
#
#    bountyLevel                                         challenges  \
# 0            0  {'12AssistStreakCount': 0, 'abilityUses': 152,...
# ...
